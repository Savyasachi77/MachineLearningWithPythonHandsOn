# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
#data_url = "http://lib.stat.cmu.edu/datasets/boston"
#raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#target = raw_df.values[1::2, 2]
boston_df = pd.read_csv('Boston.csv')
boston_df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
# Load Wages dataset
wages = pd.read_csv('Wages.csv')
# Load College dataset
college = pd.read_csv('College.csv')

# %%
# Display first 5 records of Wages dataset
print(wages.head())
# Out:
#    year  age      sex            maritl      race        education  \
# 0  2006   18  1. Male  1. Never Married  1. White     1. < HS Grad
# 1  2004   24  1. Male  1. Never Married  1. White  4. College Grad
# 2  2003   45  1. Male        2. Married  1. White  3. Some College
# 3  2003   43  1. Male        2. Married  3. Asian  4. College Grad
# 4  2005   50  1. Male       4. Divorced  1. White       2. HS Grad
#
#                region        jobclass          health health_ins   logwage  \
# 0  2. Middle Atlantic   1. Industrial       1. <=Good      2. No  4.318063
# 1  2. Middle Atlantic  2. Information  2. >=Very Good      2. No  4.255273
# 2  2. Middle Atlantic   1. Industrial       1. <=Good     1. Yes  4.875061
# 3  2. Middle Atlantic  2. Information  2. >=Very Good     1. Yes  5.041393
# 4  2. Middle Atlantic  2. Information       1. <=Good     1. Yes  4.318063
#
#          wage
# 0   75.043154
# 1   70.476020
# 2  130.982177
# 3  154.685293
# 4   75.043154

# %%
# Generate summary statistics for Wages dataset
print(wages.describe())
# Out:
#               year          age      logwage         wage
# count  3000.000000  3000.000000  3000.000000  3000.000000
# mean   2005.791000    42.414667     4.653905   111.703608
# std       2.026167    11.542406     0.351753    41.728595
# min    2003.000000    18.000000     3.000000    20.085537
# 25%    2004.000000    33.750000     4.447158    85.383940
# 50%    2006.000000    42.000000     4.653213   104.921507
# 75%    2008.000000    51.000000     4.857332   128.680488
# max    2009.000000    80.000000     5.763128   318.342430

# %%
# Print data types for Wages dataset
print(wages.dtypes)
# Out:
# year            int64
# age             int64
# sex            object
# maritl         object
# race           object
# education      object
# region         object
# jobclass       object
# health         object
# health_ins     object
# logwage       float64
# wage          float64
# dtype: object

# %%
# Check for missing values in Wages dataset
print(wages.isnull().sum())
# Out:
# year          0
# age           0
# sex           0
# maritl        0
# race          0
# education     0
# region        0
# jobclass      0
# health        0
# health_ins    0
# logwage       0
# wage          0
# dtype: int64

# %%
# Histogram
wages.hist(bins=30, figsize=(20,15), color='skyblue')
plt.show()

# %%
# Correlation for Boston Housing dataset
correlation_matrix = boston_df.corr().round(1)
plt.figure(figsize = (10,8))
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %%
# Covariance for Boston Housing dataset
covariance_matrix = boston_df.cov().round(1)
plt.figure(figsize = (14,10))
sns.heatmap(data=covariance_matrix, annot=True)
plt.show()

# %%
plt.scatter(boston_df['rad'], boston_df['chas'])
plt.xlabel('rad')
plt.ylabel('chas')
plt.show()

# %%
plt.scatter(boston_df['lstat'], boston_df['medv'])
plt.xlabel('Average number of rooms per dwelling (RM)')
plt.ylabel('Median value of owner-occupied homes in $1000s (MEDV)')
plt.show()

# %%
plt.scatter(boston_df['nox'], boston_df['dis'])
plt.xlabel('NOX')
plt.ylabel('DIS')
plt.show()

# %%
plt.scatter(boston_df['rad'], boston_df['tax'])
plt.xlabel('RAD')
plt.ylabel('TAX')
plt.show()

# %%
plt.scatter(boston_df['rm'], boston_df['medv'])
plt.xlabel('Average number of rooms per dwelling (RM)')
plt.ylabel('Median value of owner-occupied homes ($1000s, MEDV)')
plt.show()

# %%
# Apply logarithmic transformation
boston_df['LSTAT_log'] = np.log(boston_df['lstat'])
# Compare original and transformed distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(boston_df['lstat'], bins=30, ax=ax1)
ax1.set_title('Original')
sns.histplot(boston_df['LSTAT_log'], bins=30, ax=ax2)
ax2.set_title('Logarithmic transformation')
plt.show()

# %%
wages = pd.read_csv('Wages.csv')

# %%
wages.head()
# Out:
#    year  age      sex            maritl      race        education  \
# 0  2006   18  1. Male  1. Never Married  1. White     1. < HS Grad
# 1  2004   24  1. Male  1. Never Married  1. White  4. College Grad
# 2  2003   45  1. Male        2. Married  1. White  3. Some College
# 3  2003   43  1. Male        2. Married  3. Asian  4. College Grad
# 4  2005   50  1. Male       4. Divorced  1. White       2. HS Grad
#
#                region        jobclass          health health_ins   logwage  \
# 0  2. Middle Atlantic   1. Industrial       1. <=Good      2. No  4.318063
# 1  2. Middle Atlantic  2. Information  2. >=Very Good      2. No  4.255273
# 2  2. Middle Atlantic   1. Industrial       1. <=Good     1. Yes  4.875061
# 3  2. Middle Atlantic  2. Information  2. >=Very Good     1. Yes  5.041393
# 4  2. Middle Atlantic  2. Information       1. <=Good     1. Yes  4.318063
#
#          wage
# 0   75.043154
# 1   70.476020
# 2  130.982177
# 3  154.685293
# 4   75.043154

# %%
print(wages.describe())
# Out:
#               year          age      logwage         wage
# count  3000.000000  3000.000000  3000.000000  3000.000000
# mean   2005.791000    42.414667     4.653905   111.703608
# std       2.026167    11.542406     0.351753    41.728595
# min    2003.000000    18.000000     3.000000    20.085537
# 25%    2004.000000    33.750000     4.447158    85.383940
# 50%    2006.000000    42.000000     4.653213   104.921507
# 75%    2008.000000    51.000000     4.857332   128.680488
# max    2009.000000    80.000000     5.763128   318.342430

# %%
print(wages.dtypes)
# Out:
# year            int64
# age             int64
# sex            object
# maritl         object
# race           object
# education      object
# region         object
# jobclass       object
# health         object
# health_ins     object
# logwage       float64
# wage          float64
# dtype: object

# %%
print(wages.isnull().sum())
# Out:
# year          0
# age           0
# sex           0
# maritl        0
# race          0
# education     0
# region        0
# jobclass      0
# health        0
# health_ins    0
# logwage       0
# wage          0
# dtype: int64

# %%
wages.hist(bins=30, figsize=(20,15), color='skyblue')
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'logwage'}>,
#         <Axes: title={'center': 'wage'}>]], dtype=object)

# %%
# Load Wages dataset
wages = pd.read_csv('Wages.csv')
# Create pivot table
pivot = wages.pivot_table(values='wage', index='education', columns='sex',aggfunc='mean')
print(pivot)
# Out:
# sex                    1. Male
# education
# 1. < HS Grad         84.104415
# 2. HS Grad           95.783351
# 3. Some College     107.755566
# 4. College Grad     124.427908
# 5. Advanced Degree  150.917776

# %%
pivot = wages.pivot_table(values='wage', index=['education', 'race'], columns='sex', aggfunc='mean')

print(pivot)
# Out:
# sex                             1. Male
# education          race
# 1. < HS Grad       1. White   84.438136
#                    2. Black   86.830226
#                    3. Asian   75.137379
#                    4. Other   82.248988
# 2. HS Grad         1. White   96.690752
#                    2. Black   93.641405
#                    3. Asian   85.116251
#                    4. Other   81.144948
# 3. Some College    1. White  109.007354
#                    2. Black  101.395466
#                    3. Asian  100.141225
#                    4. Other  114.785048
# 4. College Grad    1. White  125.325494
#                    2. Black  111.766883
#                    3. Asian  126.329379
#                    4. Other   79.072601
# 5. Advanced Degree 1. White  152.455014
#                    2. Black  137.840085
#                    3. Asian  149.147152
#                    4. Other  106.945844

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# Step 1: Generate a dataset
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # Features
true_slope = 2.5
true_intercept = -1.5
y = true_slope * X.squeeze() + true_intercept + np.random.randn(100) * 2  # Targets with noise

# Step 2: Fit a linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Step 3: Visualize the fit
plt.scatter(X, y, color='blue', label='Data points')
line_X = np.linspace(0, 10, 100).reshape(-1, 1)
line_y = lin_reg.predict(line_X)
plt.plot(line_X, line_y, color='red', label='Linear fit')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()
plt.title('Linear Regression Fit')
plt.show()

# Step 4: Demonstrate variance by resampling the dataset and fitting the model
for i in range(5):
    sample_indices = np.random.choice(range(100), 100, replace=True)
    X_sample = X[sample_indices]
    y_sample = y[sample_indices]
    lin_reg.fit(X_sample, y_sample)
    line_y_sample = lin_reg.predict(line_X)
    plt.plot(line_X, line_y_sample, label=f'Sample {i+1}')

plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()
plt.title('Variance in Linear Regression')
plt.show()

# Step 5: Demonstrate bias-variance tradeoff with polynomial regression
degrees = [1, 4, 15]
for degree in degrees:
    poly_features = PolynomialFeatures(degree=degree, include_bias=False)
    X_poly = poly_features.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=0)
    poly_reg = LinearRegression()
    poly_reg.fit(X_train, y_train)
    y_test_pred = poly_reg.predict(X_test)
    print(f'Degree: {degree}, MSE: {mean_squared_error(y_test, y_test_pred)}')

    # Visualize the polynomial fit
    X_range_poly = poly_features.transform(line_X)
    line_y_poly = poly_reg.predict(X_range_poly)
    plt.plot(line_X, line_y_poly, label=f'Degree {degree}')

plt.scatter(X, y, color='blue', label='Data points')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()
plt.title('Bias-Variance Tradeoff with Polynomial Regression')
plt.show()
# Out:
# Degree: 1, MSE: 3.9405280596896857
# Degree: 4, MSE: 4.0962457634513685
# Degree: 15, MSE: 4.486267614929693

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import ShuffleSplit

# Define a function for generating the dataset
def true_function(X):
    return np.cos(1.5 * np.pi * X)

# Generate sample data
np.random.seed(0)
n_samples = 100
X = np.sort(np.random.rand(n_samples))
y = true_function(X) + np.random.randn(n_samples) * 0.1

# Define degrees of polynomial features to be used
degrees = [1, 3, 10]

plt.figure(figsize=(14, 5))

for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i + 1)
    
    # Create a pipeline with polynomial transformation and linear regression
    polynomial_features = PolynomialFeatures(degree=degrees[i], include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    
    # Perform 10-fold cross-validation
    cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
    
    # Calculate the learning curve values
    train_sizes, train_scores, test_scores = learning_curve(pipeline, X[:, np.newaxis], y,
                                                            cv=cv, n_jobs=1, train_sizes=np.linspace(.1, 1.0, 25))
    
    # Calculate mean and standard deviation for training set scores
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    
    # Calculate mean and standard deviation for test set scores
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    # Plot the learning curve
    ax.fill_between(train_sizes, train_scores_mean - train_scores_std,
                    train_scores_mean + train_scores_std, alpha=0.1, color="r")
    ax.fill_between(train_sizes, test_scores_mean - test_scores_std,
                    test_scores_mean + test_scores_std, alpha=0.1, color="g")
    ax.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    ax.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    ax.set_title(f"Degree {degrees[i]}")
    ax.set_xlabel("Training examples")
    ax.set_ylabel("Score")
    ax.legend(loc="best")
    
#plt.title('Learning Curves (Bias-Variance Tradeoff)')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data generation: A starry sky where each star's position is determined by linear relations and a touch of randomness
np.random.seed(0)
x = np.random.rand(100) * 10
y = 2.5 * x + np.random.randn(100) * 2

# Using the ancient method of least squares to find our line of best fit
m, b = np.polyfit(x, y, 1)

# Predicting the heavens: Calculating the y values our line predicts
y_pred = m * x + b

# Charting the cosmos: Plotting our actual data points
plt.scatter(x, y, label='Actual data', color='blue')

# Drawing the line that defines our universe's order
plt.plot(x, y_pred, color='red', label='Regression line')

# The strings of fate: Calculating and plotting the residuals
residuals = y - y_pred
for (xi, yi, ri) in zip(x, y, residuals):
    plt.plot([xi, xi], [yi, yi - ri], color='black', linestyle='--')

# Annotating our chart with the formulae of our discovered truths
plt.text(1, max(y), r'$y = mx + c$', fontsize=12, color='red')
plt.text(1, max(y) - 5, r'Residuals', fontsize=12, color='black')
plt.text(1, max(y) - 10, r'$m$: Slope', fontsize=12)
plt.text(1, max(y) - 15, r'$c$: Intercept', fontsize=12)

# Naming the axes of our charted reality
plt.xlabel('Independent variable (x)')
plt.ylabel('Dependent variable (y)')

# Legend: The key to interpreting the symbols within our celestial map
plt.legend()

# Revealing the chart to the observer
plt.savefig('Ch4Box1.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the cost function for a simple linear regression (Mean Squared Error)
def cost_function(theta0, theta1, X, y):
    m = len(y)
    predictions = theta0 + theta1 * X
    return (1/(2*m)) * np.sum((predictions - y)**2)

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Creating a meshgrid for theta0 and theta1
theta0_vals = np.linspace(-10, 14, 100)
theta1_vals = np.linspace(-1, 4, 100)
theta0_mesh, theta1_mesh = np.meshgrid(theta0_vals, theta1_vals)

# Calculate the cost function for each combination of theta0 and theta1
cost_vals = np.array([cost_function(t0, t1, X, y) for t0, t1 in zip(np.ravel(theta0_mesh), np.ravel(theta1_mesh))])
cost_vals = cost_vals.reshape(theta0_mesh.shape)

# 3D plot of the cost function
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)
ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost')
ax.set_title('3D Plot of a Cost Function')
plt.savefig('Ch4CostFunction3d.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Function to compute the Mean Squared Error
def compute_mse(X, y, theta):
    predictions = X.dot(theta)
    errors = predictions - y
    mse = (1/m) * np.sum(errors**2)
    return mse

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]
mse_path = []

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)
    mse = compute_mse(X_b, y, theta)
    mse_path.append(mse)

# Plotting the Gradient Descent Iterations on the data
plt.figure(figsize=(10, 7))
plt.scatter(X, y)
X_new = np.array([[0], [2]])
for theta in theta_path:
    y_predict = X_b.dot(theta)
    plt.plot(X, y_predict, 'r-')

plt.xlabel("X")
plt.ylabel("y")
plt.title("Gradient Descent Iterations on Data")
plt.show()

# Correcting the mismatch in dimensions for the MSE vs Iterations plot
plt.figure(figsize=(10, 7))
plt.plot(range(iterations), mse_path, 'b-')  # Adjusting the x-axis to match the length of mse_path
plt.xlabel("Iterations")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Iterations in Gradient Descent")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Function to compute the Mean Squared Error
def compute_mse(X, y, theta):
    predictions = X.dot(theta)
    errors = predictions - y
    mse = (1/m) * np.sum(errors**2)
    return mse

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]
mse_path = []

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)
    mse = compute_mse(X_b, y, theta)
    mse_path.append(mse)

# Including the initial MSE value for matching dimensions
initial_mse = compute_mse(X_b, y, theta_path[0])
mse_path_with_initial = [initial_mse] + mse_path

# Plotting the Gradient Descent Iterations on the data and MSE vs Iterations side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 7))

# Plot 1: Gradient Descent Iterations on Data
ax1.scatter(X, y)
X_new = np.linspace(0, 2, 100).reshape(100, 1)
X_new_b = np.c_[np.ones((100, 1)), X_new]

prev_y_predict = None
for i in range(len(theta_path)):
    y_predict = X_new_b.dot(theta_path[i])
    ax1.plot(X_new, y_predict, 'r-')

    # Adding direction arrows to show the progression
    if prev_y_predict is not None and i < len(theta_path) - 1:
        for j in range(0, 100, 20):
            ax1.arrow(X_new[j, 0], prev_y_predict[j, 0], 0, y_predict[j, 0] - prev_y_predict[j, 0], 
                      head_width=0.03, head_length=0.05, fc='green', ec='green')

    prev_y_predict = y_predict

ax1.set_xlabel("X")
ax1.set_ylabel("y")
ax1.set_title("Gradient Descent Iterations on Data")

# Plot 2: MSE vs Iterations in Gradient Descent
ax2.plot(range(iterations + 1), mse_path_with_initial, 'b-')
ax2.set_xlabel("Iterations")
ax2.set_ylabel("Mean Squared Error")
ax2.set_title("MSE vs Iterations in Gradient Descent")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Function to compute the Mean Squared Error
def compute_mse(X, y, theta):
    predictions = X.dot(theta)
    errors = predictions - y
    mse = (1/m) * np.sum(errors**2)
    return mse

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]
mse_path = []

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)
    mse = compute_mse(X_b, y, theta)
    mse_path.append(mse)

# Including the initial MSE value for matching dimensions
initial_mse = compute_mse(X_b, y, theta_path[0])
mse_path_with_initial = [initial_mse] + mse_path

# Plotting the Gradient Descent Iterations on the data and MSE vs Iterations side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 7))

# Plot 1: Gradient Descent Iterations on Data
ax1.scatter(X, y)
X_new = np.linspace(0, 2, 100).reshape(100, 1)
X_new_b = np.c_[np.ones((100, 1)), X_new]

prev_y_predict = None
for i in range(len(theta_path)):
    y_predict = X_new_b.dot(theta_path[i])
    ax1.plot(X_new, y_predict, 'r-')

    # Adding blue arrows with thicker ends to show the progression
    if prev_y_predict is not None and i < len(theta_path) - 1:
        for j in range(0, 100, 20):
            ax1.arrow(X_new[j, 0], prev_y_predict[j, 0], 0, y_predict[j, 0] - prev_y_predict[j, 0], 
                      head_width=0.05, head_length=0.3, fc='blue', ec='blue')

    prev_y_predict = y_predict

ax1.set_xlabel("X")
ax1.set_ylabel("y")
ax1.set_title("Gradient Descent Iterations on Data")

# Plot 2: MSE vs Iterations in Gradient Descent
ax2.plot(range(iterations + 1), mse_path_with_initial, 'b-')
ax2.set_xlabel("Iterations")
ax2.set_ylabel("Mean Squared Error")
ax2.set_title("MSE vs Iterations in Gradient Descent")

plt.show()

# %%
# Modified code to show the correspondence between each point in the MSE plot and the linear fit attempt in the left plot

import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Function to compute the Mean Squared Error
def compute_mse(X, y, theta):
    predictions = X.dot(theta)
    errors = predictions - y
    mse = (1/m) * np.sum(errors**2)
    return mse

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]
mse_path = []

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)
    mse = compute_mse(X_b, y, theta)
    mse_path.append(mse)

# Including the initial MSE value for matching dimensions
initial_mse = compute_mse(X_b, y, theta_path[0])
mse_path_with_initial = [initial_mse] + mse_path

# Plotting the Gradient Descent Iterations on the data and MSE vs Iterations side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 7))

# Plot 1: Gradient Descent Iterations on Data
ax1.scatter(X, y)
X_new = np.linspace(0, 2, 100).reshape(100, 1)
X_new_b = np.c_[np.ones((100, 1)), X_new]

prev_y_predict = None
for i in range(len(theta_path)):
    y_predict = X_new_b.dot(theta_path[i])
    ax1.plot(X_new, y_predict, 'r-')

    # Adding blue arrows with thicker ends to show the progression
    if prev_y_predict is not None and i < len(theta_path) - 1:
        for j in range(0, 100, 20):
            ax1.arrow(X_new[j, 0], prev_y_predict[j, 0], 0, y_predict[j, 0] - prev_y_predict[j, 0], 
                      head_width=0.05, head_length=0.3, fc='blue', ec='blue')

    prev_y_predict = y_predict

ax1.set_xlabel("X")
ax1.set_ylabel("y")
ax1.set_title("Gradient Descent Iterations on Data")

# Plot 2: MSE vs Iterations in Gradient Descent
ax2.plot(range(iterations + 1), mse_path_with_initial, 'b-')
ax2.scatter(range(iterations + 1), mse_path_with_initial, c='red') # Add scatter plot to highlight points
ax2.set_xlabel("Iterations")
ax2.set_ylabel("Mean Squared Error")
ax2.set_title("MSE vs Iterations in Gradient Descent")
plt.savefig('Ch4GradDescent.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Define the cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    return (1/(2*m)) * np.sum((predictions - y)**2)

# Creating a range of values for theta0 and theta1
theta0_vals = np.linspace(-10, 14, 100)
theta1_vals = np.linspace(-1, 4, 100)
theta0_mesh, theta1_mesh = np.meshgrid(theta0_vals, theta1_vals)

# Calculate the cost function for each combination of theta0 and theta1
cost_vals = np.array([cost_function(np.array([[t0], [t1]]), X_b, y) for t0, t1 in zip(np.ravel(theta0_mesh), np.ravel(theta1_mesh))])
cost_vals = cost_vals.reshape(theta0_mesh.shape)

# 3D plot of the cost function
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)
ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost Function')
ax.set_title('Cost Function Surface')

plt.show()

# %%
# Modifying the code to include the same iterations from the previous figures in the 3D plot
# and showing the movement using blue arrows

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Function to compute the Mean Squared Error
def compute_mse(X, y, theta):
    predictions = X.dot(theta)
    errors = predictions - y
    mse = (1/m) * np.sum(errors**2)
    return mse

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)

# Define the cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    return (1/(2*m)) * np.sum((predictions - y)**2)

# Creating a range of values for theta0 and theta1
theta0_vals = np.linspace(-10, 14, 100)
theta1_vals = np.linspace(-1, 4, 100)
theta0_mesh, theta1_mesh = np.meshgrid(theta0_vals, theta1_vals)

# Calculate the cost function for each combination of theta0 and theta1
cost_vals = np.array([cost_function(np.array([[t0], [t1]]), X_b, y) for t0, t1 in zip(np.ravel(theta0_mesh), np.ravel(theta1_mesh))])
cost_vals = cost_vals.reshape(theta0_mesh.shape)

# 3D plot of the cost function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)

# Plot the path of gradient descent
for i in range(len(theta_path) - 1):
    ax.quiver(theta_path[i][0], theta_path[i][1], cost_function(theta_path[i], X_b, y),
              theta_path[i+1][0] - theta_path[i][0], theta_path[i+1][1] - theta_path[i][1],
              cost_function(theta_path[i+1], X_b, y) - cost_function(theta_path[i], X_b, y),
              color='blue', length=0.1, normalize=True)

ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost Function')
ax.set_title('Cost Function Surface with Gradient Descent Path')

plt.show()

# %%
# 3D plot of the cost function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)

# Plot the path of gradient descent
for i in range(len(theta_path) - 1):
    start_point = np.append(theta_path[i], cost_function(theta_path[i], X_b, y))
    end_point = np.append(theta_path[i+1], cost_function(theta_path[i+1], X_b, y))
    arrow = end_point - start_point
    ax.quiver(*start_point, *arrow, color='blue', length=0.5, normalize=True)

ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost Function')
ax.set_title('Cost Function Surface with Gradient Descent Path')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)

# Define the cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    return (1/(2*m)) * np.sum((predictions - y)**2)

# Creating a range of values for theta0 and theta1
theta0_vals = np.linspace(-10, 14, 100)
theta1_vals = np.linspace(-1, 4, 100)
theta0_mesh, theta1_mesh = np.meshgrid(theta0_vals, theta1_vals)

# Calculate the cost function for each combination of theta0 and theta1
cost_vals = np.array([cost_function(np.array([[t0], [t1]]), X_b, y) for t0, t1 in zip(np.ravel(theta0_mesh), np.ravel(theta1_mesh))])
cost_vals = cost_vals.reshape(theta0_mesh.shape)

# 3D plot of the cost function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)

# Plot the path of gradient descent with magenta arrows and large blue points
for i in range(1, len(theta_path)):
    start_theta = theta_path[i - 1]
    end_theta = theta_path[i]
    start_cost = cost_function(start_theta, X_b, y)
    end_cost = cost_function(end_theta, X_b, y)

    # Draw arrows
    ax.quiver(start_theta[0], start_theta[1], start_cost,
              end_theta[0] - start_theta[0], end_theta[1] - start_theta[1], end_cost - start_cost,
              color='magenta', length=0.7, normalize=True)
    
    # Draw points
    ax.scatter(end_theta[0], end_theta[1], end_cost, color='blue', s=20)

ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost Function')
ax.set_title('Cost Function Surface with Gradient Descent Path')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)

# Define the cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    return (1/(2*m)) * np.sum((predictions - y)**2)

# Creating a range of values for theta0 and theta1
theta0_vals = np.linspace(-10, 14, 100)
theta1_vals = np.linspace(-1, 4, 100)
theta0_mesh, theta1_mesh = np.meshgrid(theta0_vals, theta1_vals)

# Calculate the cost function for each combination of theta0 and theta1
cost_vals = np.array([cost_function(np.array([[t0], [t1]]), X_b, y) for t0, t1 in zip(np.ravel(theta0_mesh), np.ravel(theta1_mesh))])
cost_vals = cost_vals.reshape(theta0_mesh.shape)

# 3D plot of the cost function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)

# Plot the path of gradient descent
for i in range(1, len(theta_path)):
    # Points for the start and end of the line segment
    start_theta = theta_path[i - 1].flatten()
    end_theta = theta_path[i].flatten()
    start_cost = cost_function(start_theta, X_b, y)
    end_cost = cost_function(end_theta, X_b, y)

    # Draw line segments
    ax.plot([start_theta[0], end_theta[0]], [start_theta[1], end_theta[1]], [start_cost, end_cost], color='magenta')

    # Draw points
    ax.scatter(end_theta[0], end_theta[1], end_cost, color='blue', s=50)

ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost Function')
ax.set_title('Cost Function Surface with Gradient Descent Path')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data for demonstration
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Adding a column of ones to X for the intercept term
X_b = np.c_[np.ones((100, 1)), X]

# Gradient Descent Settings
learning_rate = 0.1
iterations = 10
m = len(X_b)

# Initial parameters (theta)
theta = np.random.randn(2,1)

# Arrays to store the progress of the Gradient Descent
theta_path = [theta]

# Gradient Descent Iterations
for iteration in range(iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
    theta_path.append(theta)

# Define the cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    return (1/(2*m)) * np.sum((predictions - y)**2)

# Creating a range of values for theta0 and theta1
theta0_vals = np.linspace(-10, 14, 100)
theta1_vals = np.linspace(-1, 4, 100)
theta0_mesh, theta1_mesh = np.meshgrid(theta0_vals, theta1_vals)

# Calculate the cost function for each combination of theta0 and theta1
cost_vals = np.array([cost_function(np.array([[t0], [t1]]), X_b, y) for t0, t1 in zip(np.ravel(theta0_mesh), np.ravel(theta1_mesh))])
cost_vals = cost_vals.reshape(theta0_mesh.shape)

# 3D plot of the cost function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0_mesh, theta1_mesh, cost_vals, cmap='viridis', alpha=0.6)

# Plot the path of gradient descent
for i in range(1, len(theta_path)):
    start_theta = theta_path[i - 1].ravel()
    end_theta = theta_path[i].ravel()
    start_cost = cost_function(theta_path[i - 1], X_b, y)
    end_cost = cost_function(theta_path[i], X_b, y)

    # Draw line segments
    ax.plot([start_theta[0], end_theta[0]], [start_theta[1], end_theta[1]], [start_cost, end_cost], color='magenta')

    # Draw points
    ax.scatter(end_theta[0], end_theta[1], end_cost, color='blue', s=50)

ax.set_xlabel('Theta 0')
ax.set_ylabel('Theta 1')
ax.set_zlabel('Cost Function')
ax.set_title('Cost Function Surface with Gradient Descent Path')
plt.savefig('Ch4GradDescent3d.png')
plt.show()
